# %%
import warnings
from IPython.display import Image

# %% [markdown]
# # Graphics
#
# See more elementary examples at http://people.duke.edu/~ccc14/cfar-data-2016/index.html#day-2

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Setting up numeric environment

# %% [markdown]
# ### Setting up graphics environment

# %% [markdown]
# ### Basic plots

# %%
Image('acme_vs_ecma.png')

# %% [markdown]
# ### Using styles

# %%
Image('fivethirtyeight.png')

# %% [markdown]
# ### The special, whimsical XKCD style
#
# Only available within `pyplot`, and not via `matplotlib.style`.

# %%
Image('xkcd.png')

# %% [markdown]
# ### Other plots

# %%
Image('bar.png')

# %%
Image('scatter.png')

# %%
Image('stream.png')

# %%
Image('polar.png')

# %% [markdown]
# ### Annotations

# %%
Image('annotate.png')

# %% [markdown]
# ### Multiple plots

# %%
Image('regular.png')

# %%
Image('gridspec.png')

# %% [markdown]
# ## Seaborn

# %%
Image('displot.png')

# %%
Image('kdeplot.png')

# %% [markdown]
# ### `lmplot` and `factorplot`

# %%
Image('lmplot.png')

# %%
Image('lmplot_sep.png')

# %%
Image('lmplot_lowess.png')

# %%
Image('factor_bar.png')

# %%
Image('factor_swarm.png')

# %%
Image('factor_box.png')

# %%
Image('factor_violin.png')

# %% [markdown]
# ### Color paltettes and colormaps

# %%
Image('factor_bar_BuGn_r.png')

# %% [markdown]
# #### Sequential, divergent and qualitative plattes
#
# Choosing colorbrewer palettes.

# %%
Image('factor_bar_colorbrewer.png')
